# %% [markdown]
# # Generative Adverserial Networks in PyTorch
#
# ### Part 7 of "Deep Learning with Pytorch"
#
# Deep neural networks are used mainly for supervised learning: classification or regression. Generative Adverserial Networks or GANs, however, use neural networks for a very different purpose: Generative modeling
#
# > Generative modeling is an unsupervised learning task in machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset. - [Source](https://machinelearningmastery.com/what-are-generative-adversarial-networks-gans/)
#
# While there are many approaches used for generative modeling, a Generative Adverserial Network takes the following approach:
#
# ![GAN Flowchart](https://github.com/romainducrocq/moocs/blob/master/freecodecamp/Pytorch_For_Deep_Learning/07-mnist-gan/images/6NMdO9u.png?raw=1)
#
# There are two neural networks: a *Generator* and a *Discriminator*. The generator generates a "fake" sample given a random vector/matrix, and the discriminator attempts to detect whether a given sample is "real" (picked from the training data) or "fake" (generated by the generator). Training happens in tandem: we train the discriminator for a few epochs, then train the generator for a few epochs, and repeat. This way both the generator and the discriminator get better at doing their jobs. This rather simple approach can lead to some astounding results. The following images ([source](https://machinelearningmastery.com/resources-for-getting-started-with-generative-adversarial-networks/)), for instances, were all generated using GANs:
#
# <img src="https://github.com/romainducrocq/moocs/blob/master/freecodecamp/Pytorch_For_Deep_Learning/07-mnist-gan/images/Example-of-Photorealistic-Human-Faces-Generated-by-a-GAN.png?raw=1" alt="gans_results" width="480">
#
#
# GANs however, can be notoriously difficult to train, and are extremely sensitive to hyperparameters, activation functions and regularization. In this tutorial, we'll train a GAN to generate images of handwritten digits similar to those from the MNIST database.
#
# <img src="https://github.com/romainducrocq/moocs/blob/master/freecodecamp/Pytorch_For_Deep_Learning/07-mnist-gan/images/CAYnuo1.jpg?raw=1" width="360" >
#
# Most of the code for this tutorial has been borrowed for this excellent repository of PyTorch tutorials: [github.com/yunjey/pytorch-tutorial](https://github.com/yunjey/pytorch-tutorial). Here's what we're going to do:
#
# * Define the problem statement
# * Load the data (with transforms and normalization)
#     * Denormalize for visual inspection of samples
# * Define the Discriminator network
#     * Study the activation function: Leaky ReLU
# * Define the Generator network
#     * Explain the output activation function: TanH
#     * Look at some sample outputs
# * Define losses, optimizers and helper functions for training
#     * For discriminator
#     * For generator
# * Train the model
#     * Save intermediate generated images to file
# * Look at some outputs
# * Save the models

# %% [markdown]
# ## Load the Data
#
# We begin by downloading and importing the data as a PyTorch dataset using the `MNIST` helper class from `torchvision.datasets`.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='data/', train=True, download=True, transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to the range `[-1, 1]`. The reason for doing this will become clear when define the generator network. Let's look at a sample tensor from the data.

# %%
img, label = mnist[0]
print('Label:', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label: 5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.

# %%
def denorm(x):
  out = (x + 1) / 2
  return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 5

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
  print('fisrt_batch')
  print(img_batch.shape)
  plt.imshow(img_batch[0][0], cmap='gray')
  print(label_batch)
  break
# Out:
# fisrt_batch
# torch.Size([100, 1, 28, 28])
# tensor([3, 9, 2, 6, 7, 5, 7, 1, 9, 9, 3, 4, 6, 6, 6, 3, 5, 8, 1, 9, 7, 6, 2, 1,
#         4, 3, 4, 1, 5, 1, 1, 2, 4, 0, 7, 6, 3, 4, 1, 2, 5, 2, 0, 3, 1, 5, 2, 8,
#         9, 0, 2, 3, 4, 1, 1, 5, 7, 6, 1, 9, 1, 3, 7, 4, 1, 6, 2, 8, 9, 2, 0, 6,
#         3, 4, 3, 2, 8, 7, 7, 6, 2, 8, 5, 7, 1, 6, 6, 1, 2, 3, 6, 9, 6, 8, 6, 0,
#         9, 8, 7, 1])

# %% [markdown]
# We'll also create a `device` which can be used to move the data and models to a GPU, if one is available.

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid()
)

# %% [markdown]
# We use the Leaky ReLU activation for the discriminator.
#
# <img src="https://github.com/romainducrocq/moocs/blob/master/freecodecamp/Pytorch_For_Deep_Learning/07-mnist-gan/images/1*ypsvQH7kvtI2BhzR2eT_Sw.png?raw=1" width="420">
#
#
# >  Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flows stronger into the generator. Instead of passing a gradient (slope) of 0 in the back-prop pass, it passes a small negative gradient.  - [Source](https://sthalles.github.io/advanced_gans/)
#
# Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1, which can be interpreted as the probability of the input image being fake i.e. generated.
#
# Let's move the discriminator model to the chosen device.

# %%
D.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=256, bias=True)
#   (1): LeakyReLU(negative_slope=0.2)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): LeakyReLU(negative_slope=0.2)
#   (4): Linear(in_features=256, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %% [markdown]
# ## Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %%
latent_size = 64

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh()
)

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://github.com/romainducrocq/moocs/blob/master/freecodecamp/Pytorch_For_Deep_Learning/07-mnist-gan/images/tanh.gif?raw=1" width="420" >
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling." - [Source](https://stackoverflow.com/questions/41489907/generative-adversarial-networks-tanh)
#
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28, 28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray')

# %%
plt.imshow(gen_imgs[1], cmap='gray')

# %% [markdown]
# As one might expect, the output from the generator is basically random noise. Let's define a helper function which can save a batch of outputs from the generator to a file.
#
# Let's move the generator to the chosen device.

# %%
G.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=64, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=784, bias=True)
#   (5): Tanh()
# )

# %% [markdown]
# ## Discriminator Training
#
# Since the discriminator is a binary classification model, we can use the binary cross entropy loss function to quantify how well it is able to differentiate between real and generated images.
#
# <img src="https://github.com/romainducrocq/moocs/blob/master/freecodecamp/Pytorch_For_Deep_Learning/07-mnist-gan/images/task-based-learning-for-nlp-going-beyond-cross-entropy-chris-hokamp-10-638.jpg?raw=1" width="420" >

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %% [markdown]
# Let's define helper functions to reset gradients and  train the discriminator.

# %%
def reset_grad():
  d_optimizer.zero_grad()
  g_optimizer.zero_grad()

def train_discriminator(images):
  # Create the labels which are later used as input for the BCE loss
  real_labels = torch.ones(batch_size, 1).to(device)
  fake_labels = torch.zeros(batch_size, 1).to(device)

  # Loss for real images
  outputs = D(images)
  d_loss_real = criterion(outputs, real_labels)
  real_score = outputs

  # Loss for fake images
  z = torch.randn(batch_size, latent_size).to(device)
  fake_images = G(z)
  outputs = D(fake_images)
  d_loss_fake = criterion(outputs, fake_labels)
  fake_score = outputs

  d_loss = d_loss_real + d_loss_fake  # Combine losses
  reset_grad()                        # Reset gradients
  d_loss.backward()                   # Compute gradients
  d_optimizer.step()                  # Adjust the parameters using backprop

  return d_loss, real_score, fake_score

# %% [markdown]
# Here are the steps involved in training the discriminator.
#
# - We expect the discriminator to output 1 if the image was picked from the real MNIST dataset, and 0 if it was generated.
#
# - We first pass a batch of real images, and compute the loss, setting the target labels to 1.
#
# - Then, we generate a batch of fake images using the generator, pass them into the discriminator, and compute the loss, setting the target labels to 0.
#
# - Finally we add the two losses and use the overall loss to perform gradient descent to adjust the weights of the discriminator.
#
# It's important to note that we don't change the weights of the generator model while training the discriminator (`d_optimizer` only affects the `D.parameters()`)

# %% [markdown]
# ## Generator Training
#
# Since the outputs of the generator are images, it's not obvious how we can train the generator. This is where we employ a rather elegant trick, which is to use the discriminator as a part of the loss function. Here's how it works:
#
# - We generate a batch of images using the generator, pass the into the discriminator.
#
# - We calculate the loss by setting the target labels to 1 i.e. real. We do this because the generator's objective is to "fool" the discriminator.
#
# - We use the loss to perform gradient descent i.e. change the weights of the generator, so it gets better at generating real-like images.
#
# Here's what this looks like in code.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
  # Generate fake images and calculate loss
  z = torch.randn(batch_size, latent_size).to(device)
  fake_images = G(z)
  labels = torch.ones(batch_size, 1).to(device)
  g_loss = criterion(D(fake_images), labels)

  # Backprop and optimize
  reset_grad()
  g_loss.backward()
  g_optimizer.step()
  return g_loss, fake_images

# %% [markdown]
# ## Training the Model
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
  os.makedirs(sample_dir)

# %% [markdown]
# Let's save a batch of real images that we can use for visual comparision while looking at the generated images.

# %%
from IPython.display import Image 
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
  images = images.reshape(images.size(0), 1, 28, 28)
  save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
  break

Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# We'll also define a helper function to save a batch of generated images to disk at the end of every epoch. We'll use a fixed set of input vectors to the generator to see how the individual generated images evolve over time as we train the model.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
  fake_images = G(sample_vectors)
  fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
  fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
  print('Saving', fake_fname)
  save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
  for i, (images, _) in enumerate(data_loader):
    # Load a batch & transform to vectors
    images = images.reshape(batch_size, -1).to(device)

    # Train the discriminator and generator
    d_loss, real_score, fake_score = train_discriminator(images)
    g_loss, fake_images = train_generator()

    # Inspect the losses
    if (i+1) % 200 == 0:
      d_losses.append(d_loss.item())
      g_losses.append(g_loss.item())
      real_scores.append(real_score.mean().item())
      fake_scores.append(fake_score.mean().item())
      print("Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}".format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), real_score.mean().item(), fake_score.mean().item()))

  # Sample and save images
  save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0776, g_loss: 3.7149, D(x): 0.99, D(G(z)): 0.07
# Epoch [0/300], Step [400/600], d_loss: 0.1552, g_loss: 5.2218, D(x): 0.94, D(G(z)): 0.05
# Epoch [0/300], Step [600/600], d_loss: 0.0902, g_loss: 4.4874, D(x): 0.96, D(G(z)): 0.04
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.0336, g_loss: 5.6649, D(x): 0.99, D(G(z)): 0.02
# Epoch [1/300], Step [400/600], d_loss: 0.4504, g_loss: 3.7471, D(x): 0.86, D(G(z)): 0.19
# Epoch [1/300], Step [600/600], d_loss: 0.2253, g_loss: 4.8784, D(x): 0.97, D(G(z)): 0.16
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.1381, g_loss: 3.8017, D(x): 0.97, D(G(z)): 0.08
# Epoch [2/300], Step [400/600], d_loss: 0.7327, g_loss: 3.3656, D(x): 0.86, D(G(z)): 0.33
# Epoch [2/300], Step [600/600], d_loss: 0.3405, g_loss: 5.1008, D(x): 0.88, D(G(z)): 0.10
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.9660, g_loss: 2.0133, D(x): 0.72, D(G(z)): 0.20
# Epoch [3/300], Step [400/600], d_loss: 0.4125, g_loss: 2.8543, D(x): 0.87, D(G(z)): 0.17
# Epoch [3/300], Step [600/600], d_loss: 0.9767, g_loss: 2.2090, D(x): 0.80, D(G(z)): 0.43
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.7802, g_loss: 2.5573, D(x): 0.81, D(G(z)): 0.22
# Epoch [4/300], Step [400/600], d_loss: 0.3213, g_loss: 2.9839, D(x): 0.93, D(G(z)): 0.16
# Epoch [4/300], Step [600/600], d_loss: 0.1944, g_loss: 3.6744, D(x): 0.96, D(G(z)): 0.12
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.2465, g_loss: 2.8537, D(x): 0.90, D(G(z)): 0.05
# Epoch [5/300], Step [400/600], d_loss: 0.4418, g_loss: 2.7549, D(x): 0.83, D(G(z)): 0.09
# Epoch [5/300], Step [600/600], d_loss: 0.1065, g_loss: 4.3073, D(x): 0.96, D(G(z)): 0.03
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.1779, g_loss: 5.1764, D(x): 0.94, D(G(z)): 0.07
# Epoch [6/300], Step [400/600], d_loss: 0.1033, g_loss: 4.6196, D(x): 0.98, D(G(z)): 0.08
# Epoch [6/300], Step [600/600], d_loss: 0.1465, g_loss: 4.0579, D(x): 0.94, D(G(z)): 0.03
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.0654, g_loss: 4.7755, D(x): 0.97, D(G(z)): 0.02
# Epoch [7/300], Step [400/600], d_loss: 0.1146, g_loss: 3.5482, D(x): 0.96, D(G(z)): 0.04
# Epoch [7/300], Step [600/600], d_loss: 0.0311, g_loss: 5.4487, D(x): 0.98, D(G(z)): 0.01
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.1196, g_loss: 5.5836, D(x): 0.95, D(G(z)): 0.01
# Epoch [8/300], Step [400/600], d_loss: 0.0501, g_loss: 6.4032, D(x): 0.98, D(G(z)): 0.02
# Epoch [8/300], Step [600/600], d_loss: 0.1969, g_loss: 5.7499, D(x): 0.98, D(G(z)): 0.12
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.1217, g_loss: 5.8020, D(x): 0.97, D(G(z)): 0.03
# Epoch [9/300], Step [400/600], d_loss: 0.1193, g_loss: 5.8126, D(x): 0.97, D(G(z)): 0.05
# Epoch [9/300], Step [600/600], d_loss: 0.0771, g_loss: 7.9309, D(x): 0.99, D(G(z)): 0.02
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.0446, g_loss: 6.3495, D(x): 0.98, D(G(z)): 0.02
# Epoch [10/300], Step [400/600], d_loss: 0.1157, g_loss: 5.2362, D(x): 0.98, D(G(z)): 0.07
# Epoch [10/300], Step [600/600], d_loss: 0.1095, g_loss: 5.2140, D(x): 0.98, D(G(z)): 0.02
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.2332, g_loss: 6.0369, D(x): 0.95, D(G(z)): 0.07
# Epoch [11/300], Step [400/600], d_loss: 0.1357, g_loss: 6.6140, D(x): 0.93, D(G(z)): 0.01
# Epoch [11/300], Step [600/600], d_loss: 0.2484, g_loss: 5.2777, D(x): 0.96, D(G(z)): 0.14
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.2454, g_loss: 2.7649, D(x): 0.94, D(G(z)): 0.09
# Epoch [12/300], Step [400/600], d_loss: 0.2820, g_loss: 5.2265, D(x): 0.96, D(G(z)): 0.11
# Epoch [12/300], Step [600/600], d_loss: 0.1117, g_loss: 6.3082, D(x): 0.96, D(G(z)): 0.02
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.3110, g_loss: 3.8997, D(x): 0.96, D(G(z)): 0.18
# Epoch [13/300], Step [400/600], d_loss: 0.1539, g_loss: 4.7884, D(x): 0.96, D(G(z)): 0.06
# Epoch [13/300], Step [600/600], d_loss: 0.2426, g_loss: 4.9292, D(x): 0.92, D(G(z)): 0.06
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.1974, g_loss: 4.7324, D(x): 0.92, D(G(z)): 0.03
# Epoch [14/300], Step [400/600], d_loss: 0.2066, g_loss: 3.4587, D(x): 0.94, D(G(z)): 0.06
# Epoch [14/300], Step [600/600], d_loss: 0.2304, g_loss: 4.3582, D(x): 0.94, D(G(z)): 0.05
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.2079, g_loss: 3.7079, D(x): 0.95, D(G(z)): 0.07
# Epoch [15/300], Step [400/600], d_loss: 0.1311, g_loss: 5.0167, D(x): 0.95, D(G(z)): 0.03
# Epoch [15/300], Step [600/600], d_loss: 0.1378, g_loss: 4.2334, D(x): 0.97, D(G(z)): 0.07
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.0486, g_loss: 5.5135, D(x): 0.97, D(G(z)): 0.02
# Epoch [16/300], Step [400/600], d_loss: 0.1446, g_loss: 4.4843, D(x): 0.95, D(G(z)): 0.05
# Epoch [16/300], Step [600/600], d_loss: 0.2266, g_loss: 6.6104, D(x): 0.89, D(G(z)): 0.01
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.1807, g_loss: 5.0453, D(x): 0.96, D(G(z)): 0.07
# Epoch [17/300], Step [400/600], d_loss: 0.3836, g_loss: 5.6026, D(x): 0.88, D(G(z)): 0.02
# Epoch [17/300], Step [600/600], d_loss: 0.1991, g_loss: 3.9027, D(x): 0.97, D(G(z)): 0.13
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.1639, g_loss: 4.7571, D(x): 0.97, D(G(z)): 0.09
# Epoch [18/300], Step [400/600], d_loss: 0.0946, g_loss: 5.4620, D(x): 0.99, D(G(z)): 0.07
# Epoch [18/300], Step [600/600], d_loss: 0.2494, g_loss: 3.4455, D(x): 0.94, D(G(z)): 0.11
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.1952, g_loss: 3.8293, D(x): 0.96, D(G(z)): 0.07
# Epoch [19/300], Step [400/600], d_loss: 0.2507, g_loss: 5.9485, D(x): 0.89, D(G(z)): 0.02
# Epoch [19/300], Step [600/600], d_loss: 0.0673, g_loss: 5.5740, D(x): 0.98, D(G(z)): 0.03
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.1748, g_loss: 5.1035, D(x): 0.99, D(G(z)): 0.13
# Epoch [20/300], Step [400/600], d_loss: 0.1048, g_loss: 6.0520, D(x): 0.96, D(G(z)): 0.03
# Epoch [20/300], Step [600/600], d_loss: 0.3201, g_loss: 5.0005, D(x): 0.89, D(G(z)): 0.04
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.1672, g_loss: 5.2571, D(x): 0.95, D(G(z)): 0.07
# Epoch [21/300], Step [400/600], d_loss: 0.2676, g_loss: 5.1083, D(x): 0.88, D(G(z)): 0.03
# Epoch [21/300], Step [600/600], d_loss: 0.2137, g_loss: 3.6241, D(x): 0.95, D(G(z)): 0.09
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.2515, g_loss: 4.8273, D(x): 0.95, D(G(z)): 0.09
# Epoch [22/300], Step [400/600], d_loss: 0.3104, g_loss: 4.6784, D(x): 0.93, D(G(z)): 0.12
# Epoch [22/300], Step [600/600], d_loss: 0.2404, g_loss: 5.6268, D(x): 0.91, D(G(z)): 0.03
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.3429, g_loss: 4.2591, D(x): 0.95, D(G(z)): 0.16
# Epoch [23/300], Step [400/600], d_loss: 0.2196, g_loss: 5.4475, D(x): 0.94, D(G(z)): 0.06
# Epoch [23/300], Step [600/600], d_loss: 0.2606, g_loss: 4.8008, D(x): 0.91, D(G(z)): 0.05
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.2868, g_loss: 5.0204, D(x): 0.95, D(G(z)): 0.13
# Epoch [24/300], Step [400/600], d_loss: 0.1398, g_loss: 5.7248, D(x): 0.95, D(G(z)): 0.04
# Epoch [24/300], Step [600/600], d_loss: 0.2833, g_loss: 4.2872, D(x): 0.89, D(G(z)): 0.04
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.2837, g_loss: 3.5033, D(x): 0.93, D(G(z)): 0.11
# Epoch [25/300], Step [400/600], d_loss: 0.2865, g_loss: 5.1671, D(x): 0.88, D(G(z)): 0.01
# Epoch [25/300], Step [600/600], d_loss: 0.1885, g_loss: 5.2745, D(x): 0.94, D(G(z)): 0.07
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.1421, g_loss: 4.5921, D(x): 0.96, D(G(z)): 0.07
# Epoch [26/300], Step [400/600], d_loss: 0.2542, g_loss: 3.9763, D(x): 0.94, D(G(z)): 0.10
# Epoch [26/300], Step [600/600], d_loss: 0.1421, g_loss: 4.2408, D(x): 0.96, D(G(z)): 0.04
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.1079, g_loss: 5.3023, D(x): 0.97, D(G(z)): 0.04
# Epoch [27/300], Step [400/600], d_loss: 0.3168, g_loss: 3.3606, D(x): 0.95, D(G(z)): 0.14
# Epoch [27/300], Step [600/600], d_loss: 0.2996, g_loss: 3.5480, D(x): 0.93, D(G(z)): 0.12
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.2430, g_loss: 3.8505, D(x): 0.94, D(G(z)): 0.12
# Epoch [28/300], Step [400/600], d_loss: 0.3254, g_loss: 3.3993, D(x): 0.90, D(G(z)): 0.08
# Epoch [28/300], Step [600/600], d_loss: 0.3591, g_loss: 3.5519, D(x): 0.89, D(G(z)): 0.12
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.2709, g_loss: 3.6635, D(x): 0.93, D(G(z)): 0.11
# Epoch [29/300], Step [400/600], d_loss: 0.2941, g_loss: 4.5009, D(x): 0.92, D(G(z)): 0.11
# Epoch [29/300], Step [600/600], d_loss: 0.4202, g_loss: 3.0046, D(x): 0.95, D(G(z)): 0.23
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.1958, g_loss: 5.8587, D(x): 0.92, D(G(z)): 0.04
# Epoch [30/300], Step [400/600], d_loss: 0.2640, g_loss: 3.0300, D(x): 0.92, D(G(z)): 0.08
# Epoch [30/300], Step [600/600], d_loss: 0.3203, g_loss: 3.2141, D(x): 0.92, D(G(z)): 0.13
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.4937, g_loss: 3.9471, D(x): 0.88, D(G(z)): 0.12
# Epoch [31/300], Step [400/600], d_loss: 0.4989, g_loss: 3.1423, D(x): 0.93, D(G(z)): 0.22
# Epoch [31/300], Step [600/600], d_loss: 0.2272, g_loss: 3.0449, D(x): 0.92, D(G(z)): 0.09
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.4495, g_loss: 3.0545, D(x): 0.87, D(G(z)): 0.13
# Epoch [32/300], Step [400/600], d_loss: 0.3471, g_loss: 2.9305, D(x): 0.86, D(G(z)): 0.07
# Epoch [32/300], Step [600/600], d_loss: 0.5636, g_loss: 2.7945, D(x): 0.86, D(G(z)): 0.21
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.3819, g_loss: 2.6303, D(x): 0.91, D(G(z)): 0.14
# Epoch [33/300], Step [400/600], d_loss: 0.4077, g_loss: 2.3888, D(x): 0.86, D(G(z)): 0.11
# Epoch [33/300], Step [600/600], d_loss: 0.2548, g_loss: 4.5738, D(x): 0.91, D(G(z)): 0.05
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.4314, g_loss: 4.2006, D(x): 0.84, D(G(z)): 0.06
# Epoch [34/300], Step [400/600], d_loss: 0.3270, g_loss: 3.8209, D(x): 0.89, D(G(z)): 0.07
# Epoch [34/300], Step [600/600], d_loss: 0.3463, g_loss: 2.8244, D(x): 0.92, D(G(z)): 0.16
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.1888, g_loss: 4.8795, D(x): 0.97, D(G(z)): 0.10
# Epoch [35/300], Step [400/600], d_loss: 0.2611, g_loss: 4.7017, D(x): 0.91, D(G(z)): 0.07
# Epoch [35/300], Step [600/600], d_loss: 0.3098, g_loss: 5.0579, D(x): 0.92, D(G(z)): 0.13
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.5245, g_loss: 4.2427, D(x): 0.87, D(G(z)): 0.13
# Epoch [36/300], Step [400/600], d_loss: 0.3854, g_loss: 4.0224, D(x): 0.85, D(G(z)): 0.09
# Epoch [36/300], Step [600/600], d_loss: 0.6120, g_loss: 3.1999, D(x): 0.82, D(G(z)): 0.15
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.4398, g_loss: 4.0926, D(x): 0.87, D(G(z)): 0.09
# Epoch [37/300], Step [400/600], d_loss: 0.3917, g_loss: 2.8654, D(x): 0.88, D(G(z)): 0.12
# Epoch [37/300], Step [600/600], d_loss: 0.2965, g_loss: 3.1383, D(x): 0.89, D(G(z)): 0.08
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.3419, g_loss: 3.3912, D(x): 0.91, D(G(z)): 0.15
# Epoch [38/300], Step [400/600], d_loss: 0.5525, g_loss: 3.5913, D(x): 0.78, D(G(z)): 0.08
# Epoch [38/300], Step [600/600], d_loss: 0.3728, g_loss: 3.1181, D(x): 0.89, D(G(z)): 0.14
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.5543, g_loss: 3.4919, D(x): 0.94, D(G(z)): 0.26
# Epoch [39/300], Step [400/600], d_loss: 0.5137, g_loss: 2.4190, D(x): 0.83, D(G(z)): 0.11
# Epoch [39/300], Step [600/600], d_loss: 0.4268, g_loss: 3.4336, D(x): 0.83, D(G(z)): 0.10
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.5091, g_loss: 3.4972, D(x): 0.81, D(G(z)): 0.09
# Epoch [40/300], Step [400/600], d_loss: 0.4880, g_loss: 3.2488, D(x): 0.83, D(G(z)): 0.14
# Epoch [40/300], Step [600/600], d_loss: 0.6802, g_loss: 2.5461, D(x): 0.82, D(G(z)): 0.26
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.6532, g_loss: 3.4613, D(x): 0.79, D(G(z)): 0.16
# Epoch [41/300], Step [400/600], d_loss: 0.5585, g_loss: 2.8224, D(x): 0.80, D(G(z)): 0.13
# Epoch [41/300], Step [600/600], d_loss: 0.5640, g_loss: 3.2987, D(x): 0.79, D(G(z)): 0.15
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.6723, g_loss: 2.2951, D(x): 0.74, D(G(z)): 0.12
# Epoch [42/300], Step [400/600], d_loss: 0.5612, g_loss: 2.7696, D(x): 0.78, D(G(z)): 0.13
# Epoch [42/300], Step [600/600], d_loss: 0.6118, g_loss: 2.5435, D(x): 0.75, D(G(z)): 0.12
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.6615, g_loss: 3.0284, D(x): 0.87, D(G(z)): 0.28
# Epoch [43/300], Step [400/600], d_loss: 0.4416, g_loss: 2.6538, D(x): 0.85, D(G(z)): 0.14
# Epoch [43/300], Step [600/600], d_loss: 0.6821, g_loss: 2.8107, D(x): 0.84, D(G(z)): 0.25
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.5355, g_loss: 3.4676, D(x): 0.77, D(G(z)): 0.07
# Epoch [44/300], Step [400/600], d_loss: 0.5666, g_loss: 2.8053, D(x): 0.81, D(G(z)): 0.14
# Epoch [44/300], Step [600/600], d_loss: 0.7077, g_loss: 3.2456, D(x): 0.75, D(G(z)): 0.15
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.5740, g_loss: 3.5959, D(x): 0.80, D(G(z)): 0.10
# Epoch [45/300], Step [400/600], d_loss: 0.5970, g_loss: 2.1738, D(x): 0.84, D(G(z)): 0.24
# Epoch [45/300], Step [600/600], d_loss: 0.6384, g_loss: 2.7093, D(x): 0.82, D(G(z)): 0.20
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.6480, g_loss: 2.5539, D(x): 0.77, D(G(z)): 0.11
# Epoch [46/300], Step [400/600], d_loss: 0.5324, g_loss: 2.7503, D(x): 0.87, D(G(z)): 0.21
# Epoch [46/300], Step [600/600], d_loss: 0.4352, g_loss: 2.6762, D(x): 0.88, D(G(z)): 0.20
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.4062, g_loss: 3.7630, D(x): 0.81, D(G(z)): 0.05
# Epoch [47/300], Step [400/600], d_loss: 0.5152, g_loss: 3.6845, D(x): 0.80, D(G(z)): 0.08
# Epoch [47/300], Step [600/600], d_loss: 0.3520, g_loss: 4.3122, D(x): 0.88, D(G(z)): 0.12
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.4174, g_loss: 2.0993, D(x): 0.88, D(G(z)): 0.17
# Epoch [48/300], Step [400/600], d_loss: 0.7443, g_loss: 3.2794, D(x): 0.75, D(G(z)): 0.22
# Epoch [48/300], Step [600/600], d_loss: 0.4687, g_loss: 2.6078, D(x): 0.90, D(G(z)): 0.22
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.4855, g_loss: 3.1382, D(x): 0.81, D(G(z)): 0.12
# Epoch [49/300], Step [400/600], d_loss: 0.4643, g_loss: 3.3192, D(x): 0.84, D(G(z)): 0.13
# Epoch [49/300], Step [600/600], d_loss: 0.5540, g_loss: 2.7081, D(x): 0.81, D(G(z)): 0.18
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.5008, g_loss: 2.3534, D(x): 0.83, D(G(z)): 0.17
# Epoch [50/300], Step [400/600], d_loss: 0.4850, g_loss: 2.4077, D(x): 0.83, D(G(z)): 0.13
# Epoch [50/300], Step [600/600], d_loss: 0.5236, g_loss: 2.9226, D(x): 0.86, D(G(z)): 0.23
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.8274, g_loss: 2.4643, D(x): 0.71, D(G(z)): 0.15
# Epoch [51/300], Step [400/600], d_loss: 0.4695, g_loss: 3.2053, D(x): 0.79, D(G(z)): 0.08
# Epoch [51/300], Step [600/600], d_loss: 0.6656, g_loss: 2.7495, D(x): 0.83, D(G(z)): 0.24
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.5520, g_loss: 2.3360, D(x): 0.82, D(G(z)): 0.17
# Epoch [52/300], Step [400/600], d_loss: 0.7134, g_loss: 2.1341, D(x): 0.76, D(G(z)): 0.18
# Epoch [52/300], Step [600/600], d_loss: 0.8345, g_loss: 2.4426, D(x): 0.69, D(G(z)): 0.14
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.5016, g_loss: 2.7402, D(x): 0.81, D(G(z)): 0.12
# Epoch [53/300], Step [400/600], d_loss: 0.6573, g_loss: 2.9680, D(x): 0.75, D(G(z)): 0.11
# Epoch [53/300], Step [600/600], d_loss: 0.6764, g_loss: 2.7427, D(x): 0.75, D(G(z)): 0.12
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.6370, g_loss: 2.1002, D(x): 0.77, D(G(z)): 0.18
# Epoch [54/300], Step [400/600], d_loss: 0.6541, g_loss: 2.6207, D(x): 0.75, D(G(z)): 0.14
# Epoch [54/300], Step [600/600], d_loss: 0.6353, g_loss: 2.3980, D(x): 0.79, D(G(z)): 0.19
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.8988, g_loss: 2.5687, D(x): 0.66, D(G(z)): 0.15
# Epoch [55/300], Step [400/600], d_loss: 0.6040, g_loss: 1.9592, D(x): 0.78, D(G(z)): 0.18
# Epoch [55/300], Step [600/600], d_loss: 0.6083, g_loss: 2.3149, D(x): 0.77, D(G(z)): 0.13
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.6918, g_loss: 2.4734, D(x): 0.78, D(G(z)): 0.20
# Epoch [56/300], Step [400/600], d_loss: 0.6745, g_loss: 1.9936, D(x): 0.86, D(G(z)): 0.28
# Epoch [56/300], Step [600/600], d_loss: 0.6385, g_loss: 2.0907, D(x): 0.80, D(G(z)): 0.19
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.7436, g_loss: 1.9302, D(x): 0.72, D(G(z)): 0.17
# Epoch [57/300], Step [400/600], d_loss: 0.3935, g_loss: 2.8593, D(x): 0.88, D(G(z)): 0.15
# Epoch [57/300], Step [600/600], d_loss: 0.5221, g_loss: 3.1468, D(x): 0.84, D(G(z)): 0.16
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.6667, g_loss: 2.6772, D(x): 0.84, D(G(z)): 0.27
# Epoch [58/300], Step [400/600], d_loss: 0.5858, g_loss: 2.9027, D(x): 0.86, D(G(z)): 0.25
# Epoch [58/300], Step [600/600], d_loss: 0.4834, g_loss: 3.6635, D(x): 0.81, D(G(z)): 0.10
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.5735, g_loss: 2.4971, D(x): 0.81, D(G(z)): 0.18
# Epoch [59/300], Step [400/600], d_loss: 0.5891, g_loss: 2.7460, D(x): 0.80, D(G(z)): 0.18
# Epoch [59/300], Step [600/600], d_loss: 0.4713, g_loss: 2.6243, D(x): 0.91, D(G(z)): 0.24
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.6818, g_loss: 2.9583, D(x): 0.78, D(G(z)): 0.14
# Epoch [60/300], Step [400/600], d_loss: 0.7881, g_loss: 3.0188, D(x): 0.76, D(G(z)): 0.19
# Epoch [60/300], Step [600/600], d_loss: 0.3898, g_loss: 2.5910, D(x): 0.88, D(G(z)): 0.15
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.5468, g_loss: 2.9628, D(x): 0.92, D(G(z)): 0.28
# Epoch [61/300], Step [400/600], d_loss: 0.7011, g_loss: 2.5971, D(x): 0.77, D(G(z)): 0.19
# Epoch [61/300], Step [600/600], d_loss: 0.6418, g_loss: 2.0776, D(x): 0.82, D(G(z)): 0.23
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.5026, g_loss: 2.6810, D(x): 0.79, D(G(z)): 0.14
# Epoch [62/300], Step [400/600], d_loss: 0.5558, g_loss: 1.9700, D(x): 0.82, D(G(z)): 0.15
# Epoch [62/300], Step [600/600], d_loss: 0.5762, g_loss: 2.7409, D(x): 0.76, D(G(z)): 0.12
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.4717, g_loss: 1.9255, D(x): 0.88, D(G(z)): 0.20
# Epoch [63/300], Step [400/600], d_loss: 0.4504, g_loss: 2.0541, D(x): 0.84, D(G(z)): 0.15
# Epoch [63/300], Step [600/600], d_loss: 0.6444, g_loss: 2.5856, D(x): 0.82, D(G(z)): 0.24
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.6176, g_loss: 2.2664, D(x): 0.87, D(G(z)): 0.31
# Epoch [64/300], Step [400/600], d_loss: 0.7197, g_loss: 2.4204, D(x): 0.74, D(G(z)): 0.19
# Epoch [64/300], Step [600/600], d_loss: 0.6262, g_loss: 1.7017, D(x): 0.78, D(G(z)): 0.20
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.5119, g_loss: 1.9543, D(x): 0.89, D(G(z)): 0.24
# Epoch [65/300], Step [400/600], d_loss: 0.4712, g_loss: 2.5235, D(x): 0.82, D(G(z)): 0.13
# Epoch [65/300], Step [600/600], d_loss: 0.8540, g_loss: 2.0848, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.6870, g_loss: 1.7636, D(x): 0.82, D(G(z)): 0.26
# Epoch [66/300], Step [400/600], d_loss: 0.6455, g_loss: 1.9944, D(x): 0.72, D(G(z)): 0.12
# Epoch [66/300], Step [600/600], d_loss: 0.6090, g_loss: 3.0268, D(x): 0.79, D(G(z)): 0.17
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.5589, g_loss: 2.3011, D(x): 0.80, D(G(z)): 0.19
# Epoch [67/300], Step [400/600], d_loss: 0.4980, g_loss: 2.5965, D(x): 0.82, D(G(z)): 0.14
# Epoch [67/300], Step [600/600], d_loss: 0.6496, g_loss: 2.4167, D(x): 0.74, D(G(z)): 0.15
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.6168, g_loss: 2.0061, D(x): 0.78, D(G(z)): 0.18
# Epoch [68/300], Step [400/600], d_loss: 0.6493, g_loss: 2.5066, D(x): 0.76, D(G(z)): 0.16
# Epoch [68/300], Step [600/600], d_loss: 0.7026, g_loss: 1.8894, D(x): 0.74, D(G(z)): 0.19
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.7966, g_loss: 2.5211, D(x): 0.71, D(G(z)): 0.16
# Epoch [69/300], Step [400/600], d_loss: 0.8052, g_loss: 1.7610, D(x): 0.83, D(G(z)): 0.32
# Epoch [69/300], Step [600/600], d_loss: 0.6128, g_loss: 2.2127, D(x): 0.83, D(G(z)): 0.23
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.7210, g_loss: 1.7925, D(x): 0.80, D(G(z)): 0.28
# Epoch [70/300], Step [400/600], d_loss: 0.5259, g_loss: 2.1033, D(x): 0.79, D(G(z)): 0.14
# Epoch [70/300], Step [600/600], d_loss: 0.5783, g_loss: 2.2742, D(x): 0.86, D(G(z)): 0.24
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.6463, g_loss: 2.2864, D(x): 0.84, D(G(z)): 0.27
# Epoch [71/300], Step [400/600], d_loss: 0.5860, g_loss: 1.9538, D(x): 0.88, D(G(z)): 0.26
# Epoch [71/300], Step [600/600], d_loss: 0.6213, g_loss: 2.2861, D(x): 0.84, D(G(z)): 0.27
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.6953, g_loss: 2.3584, D(x): 0.77, D(G(z)): 0.20
# Epoch [72/300], Step [400/600], d_loss: 0.5213, g_loss: 2.5393, D(x): 0.79, D(G(z)): 0.12
# Epoch [72/300], Step [600/600], d_loss: 0.4681, g_loss: 2.2109, D(x): 0.80, D(G(z)): 0.13
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.6855, g_loss: 2.3747, D(x): 0.82, D(G(z)): 0.27
# Epoch [73/300], Step [400/600], d_loss: 0.6193, g_loss: 1.9637, D(x): 0.85, D(G(z)): 0.28
# Epoch [73/300], Step [600/600], d_loss: 0.5593, g_loss: 2.5372, D(x): 0.87, D(G(z)): 0.26
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.6999, g_loss: 2.7456, D(x): 0.74, D(G(z)): 0.14
# Epoch [74/300], Step [400/600], d_loss: 0.7307, g_loss: 2.1587, D(x): 0.80, D(G(z)): 0.29
# Epoch [74/300], Step [600/600], d_loss: 0.7643, g_loss: 2.4032, D(x): 0.79, D(G(z)): 0.26
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.5557, g_loss: 1.9319, D(x): 0.84, D(G(z)): 0.22
# Epoch [75/300], Step [400/600], d_loss: 0.8422, g_loss: 2.3847, D(x): 0.75, D(G(z)): 0.27
# Epoch [75/300], Step [600/600], d_loss: 0.8802, g_loss: 1.7445, D(x): 0.81, D(G(z)): 0.34
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.7228, g_loss: 1.8097, D(x): 0.82, D(G(z)): 0.29
# Epoch [76/300], Step [400/600], d_loss: 0.5117, g_loss: 2.2109, D(x): 0.86, D(G(z)): 0.20
# Epoch [76/300], Step [600/600], d_loss: 0.5936, g_loss: 2.6246, D(x): 0.78, D(G(z)): 0.20
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.6000, g_loss: 1.9700, D(x): 0.79, D(G(z)): 0.21
# Epoch [77/300], Step [400/600], d_loss: 0.9009, g_loss: 2.2780, D(x): 0.64, D(G(z)): 0.18
# Epoch [77/300], Step [600/600], d_loss: 0.5569, g_loss: 2.2851, D(x): 0.82, D(G(z)): 0.21
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.6870, g_loss: 1.9976, D(x): 0.76, D(G(z)): 0.23
# Epoch [78/300], Step [400/600], d_loss: 0.8831, g_loss: 1.6631, D(x): 0.90, D(G(z)): 0.41
# Epoch [78/300], Step [600/600], d_loss: 0.8222, g_loss: 1.6560, D(x): 0.74, D(G(z)): 0.24
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.6905, g_loss: 2.4627, D(x): 0.82, D(G(z)): 0.26
# Epoch [79/300], Step [400/600], d_loss: 0.7473, g_loss: 2.0029, D(x): 0.75, D(G(z)): 0.23
# Epoch [79/300], Step [600/600], d_loss: 0.8654, g_loss: 1.7984, D(x): 0.65, D(G(z)): 0.16
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.7487, g_loss: 1.9104, D(x): 0.80, D(G(z)): 0.25
# Epoch [80/300], Step [400/600], d_loss: 0.7056, g_loss: 1.9434, D(x): 0.83, D(G(z)): 0.31
# Epoch [80/300], Step [600/600], d_loss: 0.6256, g_loss: 2.2175, D(x): 0.80, D(G(z)): 0.23
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.6032, g_loss: 2.1296, D(x): 0.84, D(G(z)): 0.25
# Epoch [81/300], Step [400/600], d_loss: 0.7138, g_loss: 2.0256, D(x): 0.76, D(G(z)): 0.23
# Epoch [81/300], Step [600/600], d_loss: 0.7341, g_loss: 1.7273, D(x): 0.76, D(G(z)): 0.23
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 0.9541, g_loss: 2.4421, D(x): 0.63, D(G(z)): 0.11
# Epoch [82/300], Step [400/600], d_loss: 0.6995, g_loss: 2.3445, D(x): 0.74, D(G(z)): 0.17
# Epoch [82/300], Step [600/600], d_loss: 0.7397, g_loss: 2.1599, D(x): 0.78, D(G(z)): 0.25
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.6017, g_loss: 2.8497, D(x): 0.72, D(G(z)): 0.12
# Epoch [83/300], Step [400/600], d_loss: 0.8724, g_loss: 2.1014, D(x): 0.73, D(G(z)): 0.26
# Epoch [83/300], Step [600/600], d_loss: 0.7731, g_loss: 1.8247, D(x): 0.86, D(G(z)): 0.34
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.6794, g_loss: 2.5072, D(x): 0.77, D(G(z)): 0.21
# Epoch [84/300], Step [400/600], d_loss: 0.8318, g_loss: 1.9684, D(x): 0.71, D(G(z)): 0.21
# Epoch [84/300], Step [600/600], d_loss: 0.8042, g_loss: 1.9769, D(x): 0.72, D(G(z)): 0.22
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.7957, g_loss: 1.7505, D(x): 0.72, D(G(z)): 0.27
# Epoch [85/300], Step [400/600], d_loss: 0.7582, g_loss: 1.6464, D(x): 0.78, D(G(z)): 0.26
# Epoch [85/300], Step [600/600], d_loss: 0.7438, g_loss: 1.5442, D(x): 0.80, D(G(z)): 0.28
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.7864, g_loss: 2.5827, D(x): 0.68, D(G(z)): 0.18
# Epoch [86/300], Step [400/600], d_loss: 0.8184, g_loss: 1.8276, D(x): 0.75, D(G(z)): 0.27
# Epoch [86/300], Step [600/600], d_loss: 0.5736, g_loss: 2.1519, D(x): 0.73, D(G(z)): 0.13
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.8084, g_loss: 1.6444, D(x): 0.71, D(G(z)): 0.20
# Epoch [87/300], Step [400/600], d_loss: 0.7361, g_loss: 1.8509, D(x): 0.87, D(G(z)): 0.35
# Epoch [87/300], Step [600/600], d_loss: 0.6606, g_loss: 2.5273, D(x): 0.81, D(G(z)): 0.25
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.7973, g_loss: 1.3875, D(x): 0.72, D(G(z)): 0.23
# Epoch [88/300], Step [400/600], d_loss: 1.1395, g_loss: 1.6507, D(x): 0.69, D(G(z)): 0.36
# Epoch [88/300], Step [600/600], d_loss: 0.7651, g_loss: 2.3336, D(x): 0.72, D(G(z)): 0.21
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.7093, g_loss: 1.9878, D(x): 0.77, D(G(z)): 0.22
# Epoch [89/300], Step [400/600], d_loss: 0.7980, g_loss: 2.1569, D(x): 0.76, D(G(z)): 0.27
# Epoch [89/300], Step [600/600], d_loss: 0.8821, g_loss: 2.1616, D(x): 0.69, D(G(z)): 0.22
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.8263, g_loss: 1.8863, D(x): 0.71, D(G(z)): 0.20
# Epoch [90/300], Step [400/600], d_loss: 0.9052, g_loss: 1.9150, D(x): 0.73, D(G(z)): 0.32
# Epoch [90/300], Step [600/600], d_loss: 0.8443, g_loss: 1.4525, D(x): 0.74, D(G(z)): 0.27
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.7135, g_loss: 2.1274, D(x): 0.81, D(G(z)): 0.29
# Epoch [91/300], Step [400/600], d_loss: 0.4833, g_loss: 1.9314, D(x): 0.85, D(G(z)): 0.21
# Epoch [91/300], Step [600/600], d_loss: 0.7040, g_loss: 2.7575, D(x): 0.68, D(G(z)): 0.12
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.6346, g_loss: 2.4537, D(x): 0.69, D(G(z)): 0.10
# Epoch [92/300], Step [400/600], d_loss: 0.8294, g_loss: 2.1565, D(x): 0.77, D(G(z)): 0.28
# Epoch [92/300], Step [600/600], d_loss: 0.6775, g_loss: 1.7634, D(x): 0.84, D(G(z)): 0.28
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.6460, g_loss: 1.6532, D(x): 0.78, D(G(z)): 0.23
# Epoch [93/300], Step [400/600], d_loss: 0.6155, g_loss: 2.8592, D(x): 0.79, D(G(z)): 0.20
# Epoch [93/300], Step [600/600], d_loss: 0.8146, g_loss: 1.3498, D(x): 0.75, D(G(z)): 0.26
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.7892, g_loss: 1.7936, D(x): 0.74, D(G(z)): 0.26
# Epoch [94/300], Step [400/600], d_loss: 0.6931, g_loss: 1.9097, D(x): 0.74, D(G(z)): 0.19
# Epoch [94/300], Step [600/600], d_loss: 0.7305, g_loss: 1.8845, D(x): 0.85, D(G(z)): 0.33
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.5762, g_loss: 2.0803, D(x): 0.79, D(G(z)): 0.20
# Epoch [95/300], Step [400/600], d_loss: 0.7291, g_loss: 1.6728, D(x): 0.77, D(G(z)): 0.25
# Epoch [95/300], Step [600/600], d_loss: 0.6495, g_loss: 1.9175, D(x): 0.82, D(G(z)): 0.24
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.6714, g_loss: 2.0536, D(x): 0.78, D(G(z)): 0.23
# Epoch [96/300], Step [400/600], d_loss: 0.8206, g_loss: 1.7264, D(x): 0.77, D(G(z)): 0.30
# Epoch [96/300], Step [600/600], d_loss: 0.9973, g_loss: 1.7775, D(x): 0.72, D(G(z)): 0.37
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.7957, g_loss: 1.6221, D(x): 0.77, D(G(z)): 0.27
# Epoch [97/300], Step [400/600], d_loss: 0.6941, g_loss: 2.0837, D(x): 0.81, D(G(z)): 0.29
# Epoch [97/300], Step [600/600], d_loss: 0.7489, g_loss: 1.8736, D(x): 0.70, D(G(z)): 0.18
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 0.9850, g_loss: 1.8970, D(x): 0.77, D(G(z)): 0.33
# Epoch [98/300], Step [400/600], d_loss: 0.7733, g_loss: 1.7877, D(x): 0.79, D(G(z)): 0.28
# Epoch [98/300], Step [600/600], d_loss: 1.0388, g_loss: 2.3713, D(x): 0.61, D(G(z)): 0.20
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.6938, g_loss: 2.3889, D(x): 0.80, D(G(z)): 0.25
# Epoch [99/300], Step [400/600], d_loss: 0.8929, g_loss: 1.7320, D(x): 0.71, D(G(z)): 0.26
# Epoch [99/300], Step [600/600], d_loss: 0.6554, g_loss: 1.8469, D(x): 0.79, D(G(z)): 0.24
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.7441, g_loss: 1.8807, D(x): 0.73, D(G(z)): 0.21
# Epoch [100/300], Step [400/600], d_loss: 0.7874, g_loss: 1.9455, D(x): 0.73, D(G(z)): 0.26
# Epoch [100/300], Step [600/600], d_loss: 0.7501, g_loss: 1.7190, D(x): 0.71, D(G(z)): 0.19
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 0.9504, g_loss: 1.6126, D(x): 0.72, D(G(z)): 0.31
# Epoch [101/300], Step [400/600], d_loss: 0.6397, g_loss: 2.1455, D(x): 0.75, D(G(z)): 0.18
# Epoch [101/300], Step [600/600], d_loss: 0.7794, g_loss: 1.6217, D(x): 0.76, D(G(z)): 0.28
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 0.9609, g_loss: 1.2537, D(x): 0.80, D(G(z)): 0.39
# Epoch [102/300], Step [400/600], d_loss: 0.6330, g_loss: 1.5834, D(x): 0.85, D(G(z)): 0.28
# Epoch [102/300], Step [600/600], d_loss: 0.8379, g_loss: 1.8896, D(x): 0.69, D(G(z)): 0.20
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.6544, g_loss: 1.3624, D(x): 0.80, D(G(z)): 0.26
# Epoch [103/300], Step [400/600], d_loss: 0.6713, g_loss: 2.1227, D(x): 0.78, D(G(z)): 0.23
# Epoch [103/300], Step [600/600], d_loss: 0.7703, g_loss: 2.1535, D(x): 0.77, D(G(z)): 0.27
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.7819, g_loss: 1.7361, D(x): 0.79, D(G(z)): 0.30
# Epoch [104/300], Step [400/600], d_loss: 0.7923, g_loss: 1.9782, D(x): 0.78, D(G(z)): 0.31
# Epoch [104/300], Step [600/600], d_loss: 1.0282, g_loss: 1.4601, D(x): 0.82, D(G(z)): 0.43
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.6515, g_loss: 2.3927, D(x): 0.76, D(G(z)): 0.20
# Epoch [105/300], Step [400/600], d_loss: 0.7224, g_loss: 1.6791, D(x): 0.73, D(G(z)): 0.21
# Epoch [105/300], Step [600/600], d_loss: 0.6589, g_loss: 1.9775, D(x): 0.79, D(G(z)): 0.23
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 0.8426, g_loss: 1.6584, D(x): 0.73, D(G(z)): 0.26
# Epoch [106/300], Step [400/600], d_loss: 0.8464, g_loss: 1.8808, D(x): 0.71, D(G(z)): 0.23
# Epoch [106/300], Step [600/600], d_loss: 0.7057, g_loss: 2.2346, D(x): 0.79, D(G(z)): 0.27
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 0.8171, g_loss: 2.4803, D(x): 0.72, D(G(z)): 0.24
# Epoch [107/300], Step [400/600], d_loss: 0.8225, g_loss: 1.7051, D(x): 0.77, D(G(z)): 0.29
# Epoch [107/300], Step [600/600], d_loss: 0.8010, g_loss: 2.1744, D(x): 0.76, D(G(z)): 0.26
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 0.6201, g_loss: 1.8967, D(x): 0.80, D(G(z)): 0.23
# Epoch [108/300], Step [400/600], d_loss: 0.7965, g_loss: 1.6311, D(x): 0.78, D(G(z)): 0.29
# Epoch [108/300], Step [600/600], d_loss: 0.8738, g_loss: 2.0384, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 0.7096, g_loss: 2.1841, D(x): 0.74, D(G(z)): 0.18
# Epoch [109/300], Step [400/600], d_loss: 1.1816, g_loss: 1.4576, D(x): 0.64, D(G(z)): 0.34
# Epoch [109/300], Step [600/600], d_loss: 0.8728, g_loss: 1.4770, D(x): 0.66, D(G(z)): 0.20
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.8072, g_loss: 2.0404, D(x): 0.69, D(G(z)): 0.22
# Epoch [110/300], Step [400/600], d_loss: 0.7942, g_loss: 2.2568, D(x): 0.78, D(G(z)): 0.27
# Epoch [110/300], Step [600/600], d_loss: 0.7809, g_loss: 1.9476, D(x): 0.76, D(G(z)): 0.26
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.8209, g_loss: 2.2212, D(x): 0.75, D(G(z)): 0.26
# Epoch [111/300], Step [400/600], d_loss: 0.9307, g_loss: 1.6968, D(x): 0.73, D(G(z)): 0.32
# Epoch [111/300], Step [600/600], d_loss: 0.9774, g_loss: 1.5173, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.7630, g_loss: 1.9183, D(x): 0.71, D(G(z)): 0.19
# Epoch [112/300], Step [400/600], d_loss: 0.7969, g_loss: 2.0430, D(x): 0.70, D(G(z)): 0.23
# Epoch [112/300], Step [600/600], d_loss: 0.7970, g_loss: 1.8265, D(x): 0.76, D(G(z)): 0.28
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.6134, g_loss: 2.1400, D(x): 0.79, D(G(z)): 0.21
# Epoch [113/300], Step [400/600], d_loss: 0.9154, g_loss: 1.6549, D(x): 0.71, D(G(z)): 0.31
# Epoch [113/300], Step [600/600], d_loss: 0.7218, g_loss: 2.0695, D(x): 0.73, D(G(z)): 0.21
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 0.9242, g_loss: 1.6020, D(x): 0.70, D(G(z)): 0.28
# Epoch [114/300], Step [400/600], d_loss: 0.7671, g_loss: 2.0485, D(x): 0.78, D(G(z)): 0.31
# Epoch [114/300], Step [600/600], d_loss: 1.0075, g_loss: 1.9564, D(x): 0.69, D(G(z)): 0.30
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 0.8596, g_loss: 2.4487, D(x): 0.75, D(G(z)): 0.27
# Epoch [115/300], Step [400/600], d_loss: 0.8322, g_loss: 1.9877, D(x): 0.70, D(G(z)): 0.24
# Epoch [115/300], Step [600/600], d_loss: 1.0929, g_loss: 1.5493, D(x): 0.67, D(G(z)): 0.32
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 0.8492, g_loss: 1.9919, D(x): 0.70, D(G(z)): 0.23
# Epoch [116/300], Step [400/600], d_loss: 0.7944, g_loss: 1.4825, D(x): 0.83, D(G(z)): 0.34
# Epoch [116/300], Step [600/600], d_loss: 0.9959, g_loss: 1.4918, D(x): 0.60, D(G(z)): 0.20
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 0.6979, g_loss: 2.1597, D(x): 0.72, D(G(z)): 0.21
# Epoch [117/300], Step [400/600], d_loss: 0.9037, g_loss: 1.5420, D(x): 0.64, D(G(z)): 0.20
# Epoch [117/300], Step [600/600], d_loss: 0.7655, g_loss: 2.0606, D(x): 0.76, D(G(z)): 0.26
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 1.2509, g_loss: 1.9064, D(x): 0.72, D(G(z)): 0.41
# Epoch [118/300], Step [400/600], d_loss: 0.7480, g_loss: 2.0131, D(x): 0.82, D(G(z)): 0.31
# Epoch [118/300], Step [600/600], d_loss: 0.8408, g_loss: 1.8300, D(x): 0.72, D(G(z)): 0.28
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 0.7503, g_loss: 1.9687, D(x): 0.77, D(G(z)): 0.25
# Epoch [119/300], Step [400/600], d_loss: 0.8007, g_loss: 1.5384, D(x): 0.79, D(G(z)): 0.33
# Epoch [119/300], Step [600/600], d_loss: 0.7738, g_loss: 1.4538, D(x): 0.72, D(G(z)): 0.24
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 0.7410, g_loss: 1.4584, D(x): 0.76, D(G(z)): 0.26
# Epoch [120/300], Step [400/600], d_loss: 0.8313, g_loss: 1.6731, D(x): 0.74, D(G(z)): 0.27
# Epoch [120/300], Step [600/600], d_loss: 0.9125, g_loss: 2.0195, D(x): 0.62, D(G(z)): 0.17
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.8457, g_loss: 1.6807, D(x): 0.69, D(G(z)): 0.26
# Epoch [121/300], Step [400/600], d_loss: 0.8676, g_loss: 1.5195, D(x): 0.73, D(G(z)): 0.33
# Epoch [121/300], Step [600/600], d_loss: 0.8459, g_loss: 1.8132, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 0.8251, g_loss: 1.7096, D(x): 0.81, D(G(z)): 0.36
# Epoch [122/300], Step [400/600], d_loss: 0.7947, g_loss: 1.7116, D(x): 0.74, D(G(z)): 0.27
# Epoch [122/300], Step [600/600], d_loss: 0.7474, g_loss: 1.9477, D(x): 0.80, D(G(z)): 0.30
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 0.9720, g_loss: 1.4778, D(x): 0.63, D(G(z)): 0.24
# Epoch [123/300], Step [400/600], d_loss: 1.0782, g_loss: 1.5970, D(x): 0.58, D(G(z)): 0.19
# Epoch [123/300], Step [600/600], d_loss: 0.8650, g_loss: 1.8545, D(x): 0.67, D(G(z)): 0.22
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 0.8229, g_loss: 1.7948, D(x): 0.77, D(G(z)): 0.32
# Epoch [124/300], Step [400/600], d_loss: 0.8684, g_loss: 1.8401, D(x): 0.66, D(G(z)): 0.21
# Epoch [124/300], Step [600/600], d_loss: 0.7319, g_loss: 1.7776, D(x): 0.71, D(G(z)): 0.20
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 0.7778, g_loss: 2.0234, D(x): 0.75, D(G(z)): 0.28
# Epoch [125/300], Step [400/600], d_loss: 0.7830, g_loss: 1.8169, D(x): 0.73, D(G(z)): 0.28
# Epoch [125/300], Step [600/600], d_loss: 0.7460, g_loss: 2.2070, D(x): 0.70, D(G(z)): 0.20
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 0.8471, g_loss: 1.8091, D(x): 0.72, D(G(z)): 0.26
# Epoch [126/300], Step [400/600], d_loss: 1.0438, g_loss: 1.8296, D(x): 0.75, D(G(z)): 0.38
# Epoch [126/300], Step [600/600], d_loss: 1.0453, g_loss: 1.8288, D(x): 0.65, D(G(z)): 0.27
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 1.0386, g_loss: 1.3352, D(x): 0.73, D(G(z)): 0.36
# Epoch [127/300], Step [400/600], d_loss: 0.8250, g_loss: 1.7884, D(x): 0.68, D(G(z)): 0.23
# Epoch [127/300], Step [600/600], d_loss: 0.8203, g_loss: 1.4288, D(x): 0.82, D(G(z)): 0.35
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 0.7085, g_loss: 1.9109, D(x): 0.75, D(G(z)): 0.25
# Epoch [128/300], Step [400/600], d_loss: 1.0074, g_loss: 1.4782, D(x): 0.67, D(G(z)): 0.30
# Epoch [128/300], Step [600/600], d_loss: 0.8335, g_loss: 1.9630, D(x): 0.78, D(G(z)): 0.30
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 0.7764, g_loss: 1.9287, D(x): 0.76, D(G(z)): 0.29
# Epoch [129/300], Step [400/600], d_loss: 0.7585, g_loss: 2.0840, D(x): 0.74, D(G(z)): 0.23
# Epoch [129/300], Step [600/600], d_loss: 1.0487, g_loss: 1.4729, D(x): 0.71, D(G(z)): 0.38
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.7937, g_loss: 1.9133, D(x): 0.72, D(G(z)): 0.27
# Epoch [130/300], Step [400/600], d_loss: 0.9251, g_loss: 1.9091, D(x): 0.66, D(G(z)): 0.24
# Epoch [130/300], Step [600/600], d_loss: 0.8622, g_loss: 2.2706, D(x): 0.63, D(G(z)): 0.19
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 0.8374, g_loss: 1.3467, D(x): 0.79, D(G(z)): 0.32
# Epoch [131/300], Step [400/600], d_loss: 1.1428, g_loss: 2.0930, D(x): 0.66, D(G(z)): 0.34
# Epoch [131/300], Step [600/600], d_loss: 0.9207, g_loss: 1.8648, D(x): 0.65, D(G(z)): 0.23
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 1.0478, g_loss: 1.4486, D(x): 0.64, D(G(z)): 0.29
# Epoch [132/300], Step [400/600], d_loss: 0.7396, g_loss: 2.1735, D(x): 0.69, D(G(z)): 0.18
# Epoch [132/300], Step [600/600], d_loss: 0.7744, g_loss: 1.8865, D(x): 0.72, D(G(z)): 0.25
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 1.1715, g_loss: 1.4165, D(x): 0.62, D(G(z)): 0.29
# Epoch [133/300], Step [400/600], d_loss: 1.0190, g_loss: 2.0923, D(x): 0.67, D(G(z)): 0.30
# Epoch [133/300], Step [600/600], d_loss: 0.7519, g_loss: 1.6371, D(x): 0.75, D(G(z)): 0.28
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.9454, g_loss: 1.5964, D(x): 0.66, D(G(z)): 0.23
# Epoch [134/300], Step [400/600], d_loss: 0.8242, g_loss: 2.0546, D(x): 0.69, D(G(z)): 0.21
# Epoch [134/300], Step [600/600], d_loss: 1.0591, g_loss: 1.8954, D(x): 0.65, D(G(z)): 0.27
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 0.8197, g_loss: 1.7615, D(x): 0.71, D(G(z)): 0.26
# Epoch [135/300], Step [400/600], d_loss: 0.9224, g_loss: 1.8427, D(x): 0.72, D(G(z)): 0.32
# Epoch [135/300], Step [600/600], d_loss: 0.9133, g_loss: 1.8830, D(x): 0.65, D(G(z)): 0.24
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 0.9492, g_loss: 1.5881, D(x): 0.66, D(G(z)): 0.28
# Epoch [136/300], Step [400/600], d_loss: 0.6326, g_loss: 2.0989, D(x): 0.73, D(G(z)): 0.18
# Epoch [136/300], Step [600/600], d_loss: 0.8497, g_loss: 1.5720, D(x): 0.74, D(G(z)): 0.31
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.8062, g_loss: 1.8204, D(x): 0.71, D(G(z)): 0.24
# Epoch [137/300], Step [400/600], d_loss: 0.7541, g_loss: 1.4725, D(x): 0.78, D(G(z)): 0.30
# Epoch [137/300], Step [600/600], d_loss: 0.8114, g_loss: 1.7311, D(x): 0.71, D(G(z)): 0.24
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 0.9037, g_loss: 1.9051, D(x): 0.74, D(G(z)): 0.31
# Epoch [138/300], Step [400/600], d_loss: 0.8371, g_loss: 1.6838, D(x): 0.75, D(G(z)): 0.27
# Epoch [138/300], Step [600/600], d_loss: 1.0110, g_loss: 1.5761, D(x): 0.68, D(G(z)): 0.30
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 0.9837, g_loss: 2.0075, D(x): 0.66, D(G(z)): 0.31
# Epoch [139/300], Step [400/600], d_loss: 0.8816, g_loss: 1.5831, D(x): 0.76, D(G(z)): 0.35
# Epoch [139/300], Step [600/600], d_loss: 0.9785, g_loss: 1.6320, D(x): 0.70, D(G(z)): 0.31
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 1.0609, g_loss: 1.4427, D(x): 0.60, D(G(z)): 0.25
# Epoch [140/300], Step [400/600], d_loss: 0.8489, g_loss: 1.3402, D(x): 0.80, D(G(z)): 0.37
# Epoch [140/300], Step [600/600], d_loss: 0.9829, g_loss: 1.5277, D(x): 0.68, D(G(z)): 0.32
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.7113, g_loss: 1.5297, D(x): 0.79, D(G(z)): 0.27
# Epoch [141/300], Step [400/600], d_loss: 0.9984, g_loss: 1.5249, D(x): 0.60, D(G(z)): 0.22
# Epoch [141/300], Step [600/600], d_loss: 0.9463, g_loss: 1.4784, D(x): 0.67, D(G(z)): 0.29
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 0.8961, g_loss: 1.7170, D(x): 0.68, D(G(z)): 0.25
# Epoch [142/300], Step [400/600], d_loss: 0.8975, g_loss: 1.7747, D(x): 0.65, D(G(z)): 0.23
# Epoch [142/300], Step [600/600], d_loss: 0.8446, g_loss: 1.5406, D(x): 0.77, D(G(z)): 0.33
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.8097, g_loss: 1.5310, D(x): 0.72, D(G(z)): 0.26
# Epoch [143/300], Step [400/600], d_loss: 0.7978, g_loss: 1.7161, D(x): 0.72, D(G(z)): 0.24
# Epoch [143/300], Step [600/600], d_loss: 0.8330, g_loss: 1.5876, D(x): 0.77, D(G(z)): 0.31
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.8356, g_loss: 1.7235, D(x): 0.71, D(G(z)): 0.28
# Epoch [144/300], Step [400/600], d_loss: 0.7445, g_loss: 1.8883, D(x): 0.75, D(G(z)): 0.26
# Epoch [144/300], Step [600/600], d_loss: 0.8157, g_loss: 1.8221, D(x): 0.67, D(G(z)): 0.22
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 1.0713, g_loss: 1.8113, D(x): 0.72, D(G(z)): 0.36
# Epoch [145/300], Step [400/600], d_loss: 1.0077, g_loss: 1.8056, D(x): 0.73, D(G(z)): 0.36
# Epoch [145/300], Step [600/600], d_loss: 0.7953, g_loss: 2.0003, D(x): 0.75, D(G(z)): 0.26
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.8456, g_loss: 1.4858, D(x): 0.68, D(G(z)): 0.24
# Epoch [146/300], Step [400/600], d_loss: 1.0513, g_loss: 1.3708, D(x): 0.78, D(G(z)): 0.41
# Epoch [146/300], Step [600/600], d_loss: 0.9691, g_loss: 1.5742, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 0.8951, g_loss: 1.5714, D(x): 0.70, D(G(z)): 0.28
# Epoch [147/300], Step [400/600], d_loss: 0.9025, g_loss: 1.6051, D(x): 0.77, D(G(z)): 0.35
# Epoch [147/300], Step [600/600], d_loss: 0.8986, g_loss: 1.5484, D(x): 0.71, D(G(z)): 0.31
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 0.8789, g_loss: 1.6235, D(x): 0.64, D(G(z)): 0.19
# Epoch [148/300], Step [400/600], d_loss: 0.8867, g_loss: 1.6661, D(x): 0.65, D(G(z)): 0.24
# Epoch [148/300], Step [600/600], d_loss: 1.0356, g_loss: 2.2009, D(x): 0.63, D(G(z)): 0.27
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 0.9554, g_loss: 1.2947, D(x): 0.72, D(G(z)): 0.35
# Epoch [149/300], Step [400/600], d_loss: 0.8747, g_loss: 1.9761, D(x): 0.74, D(G(z)): 0.31
# Epoch [149/300], Step [600/600], d_loss: 1.0847, g_loss: 1.8939, D(x): 0.60, D(G(z)): 0.25
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 0.7294, g_loss: 1.6973, D(x): 0.72, D(G(z)): 0.23
# Epoch [150/300], Step [400/600], d_loss: 0.8658, g_loss: 1.2869, D(x): 0.74, D(G(z)): 0.33
# Epoch [150/300], Step [600/600], d_loss: 0.9246, g_loss: 1.6577, D(x): 0.70, D(G(z)): 0.32
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.9241, g_loss: 0.9818, D(x): 0.71, D(G(z)): 0.30
# Epoch [151/300], Step [400/600], d_loss: 0.8793, g_loss: 1.9887, D(x): 0.71, D(G(z)): 0.28
# Epoch [151/300], Step [600/600], d_loss: 0.7991, g_loss: 2.1035, D(x): 0.70, D(G(z)): 0.22
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.7262, g_loss: 1.5638, D(x): 0.74, D(G(z)): 0.25
# Epoch [152/300], Step [400/600], d_loss: 0.9479, g_loss: 1.0838, D(x): 0.78, D(G(z)): 0.38
# Epoch [152/300], Step [600/600], d_loss: 0.9537, g_loss: 2.0786, D(x): 0.74, D(G(z)): 0.34
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 0.9207, g_loss: 1.3919, D(x): 0.73, D(G(z)): 0.32
# Epoch [153/300], Step [400/600], d_loss: 1.1598, g_loss: 2.0121, D(x): 0.69, D(G(z)): 0.37
# Epoch [153/300], Step [600/600], d_loss: 0.6546, g_loss: 1.8838, D(x): 0.80, D(G(z)): 0.27
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 0.9028, g_loss: 1.6146, D(x): 0.75, D(G(z)): 0.33
# Epoch [154/300], Step [400/600], d_loss: 0.8131, g_loss: 1.6428, D(x): 0.70, D(G(z)): 0.28
# Epoch [154/300], Step [600/600], d_loss: 0.8299, g_loss: 1.5651, D(x): 0.70, D(G(z)): 0.26
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 0.8782, g_loss: 1.7837, D(x): 0.70, D(G(z)): 0.28
# Epoch [155/300], Step [400/600], d_loss: 0.9943, g_loss: 1.8578, D(x): 0.65, D(G(z)): 0.24
# Epoch [155/300], Step [600/600], d_loss: 1.0451, g_loss: 1.8934, D(x): 0.63, D(G(z)): 0.28
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 0.7257, g_loss: 1.8792, D(x): 0.80, D(G(z)): 0.30
# Epoch [156/300], Step [400/600], d_loss: 0.9768, g_loss: 1.3726, D(x): 0.77, D(G(z)): 0.39
# Epoch [156/300], Step [600/600], d_loss: 1.0931, g_loss: 1.6538, D(x): 0.64, D(G(z)): 0.31
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 0.8105, g_loss: 1.7234, D(x): 0.73, D(G(z)): 0.27
# Epoch [157/300], Step [400/600], d_loss: 1.0554, g_loss: 1.3092, D(x): 0.63, D(G(z)): 0.28
# Epoch [157/300], Step [600/600], d_loss: 1.0209, g_loss: 1.5306, D(x): 0.72, D(G(z)): 0.36
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 0.8431, g_loss: 1.6585, D(x): 0.72, D(G(z)): 0.29
# Epoch [158/300], Step [400/600], d_loss: 0.8368, g_loss: 1.8042, D(x): 0.74, D(G(z)): 0.30
# Epoch [158/300], Step [600/600], d_loss: 0.9874, g_loss: 1.5904, D(x): 0.68, D(G(z)): 0.27
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 0.9830, g_loss: 2.4122, D(x): 0.61, D(G(z)): 0.20
# Epoch [159/300], Step [400/600], d_loss: 0.8382, g_loss: 1.3699, D(x): 0.71, D(G(z)): 0.27
# Epoch [159/300], Step [600/600], d_loss: 0.7329, g_loss: 1.3748, D(x): 0.80, D(G(z)): 0.31
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 0.9370, g_loss: 1.5650, D(x): 0.69, D(G(z)): 0.29
# ...
# Epoch [247/300], Step [400/600], d_loss: 0.8858, g_loss: 1.7834, D(x): 0.67, D(G(z)): 0.26
# Epoch [247/300], Step [600/600], d_loss: 0.8627, g_loss: 1.6895, D(x): 0.71, D(G(z)): 0.27
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.8035, g_loss: 2.0109, D(x): 0.72, D(G(z)): 0.27
# Epoch [248/300], Step [400/600], d_loss: 0.9523, g_loss: 1.6194, D(x): 0.63, D(G(z)): 0.24
# Epoch [248/300], Step [600/600], d_loss: 1.0207, g_loss: 1.1511, D(x): 0.68, D(G(z)): 0.34
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 0.7764, g_loss: 1.6353, D(x): 0.74, D(G(z)): 0.25
# Epoch [249/300], Step [400/600], d_loss: 0.8992, g_loss: 1.4012, D(x): 0.66, D(G(z)): 0.25
# Epoch [249/300], Step [600/600], d_loss: 0.9262, g_loss: 1.7126, D(x): 0.65, D(G(z)): 0.27
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 0.9407, g_loss: 1.4270, D(x): 0.70, D(G(z)): 0.33
# Epoch [250/300], Step [400/600], d_loss: 0.8354, g_loss: 1.4932, D(x): 0.72, D(G(z)): 0.29
# Epoch [250/300], Step [600/600], d_loss: 1.0927, g_loss: 1.3826, D(x): 0.61, D(G(z)): 0.30
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.9937, g_loss: 1.2971, D(x): 0.62, D(G(z)): 0.29
# Epoch [251/300], Step [400/600], d_loss: 0.9631, g_loss: 1.3074, D(x): 0.67, D(G(z)): 0.28
# Epoch [251/300], Step [600/600], d_loss: 0.9064, g_loss: 1.5124, D(x): 0.74, D(G(z)): 0.34
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 1.0309, g_loss: 1.5847, D(x): 0.69, D(G(z)): 0.33
# Epoch [252/300], Step [400/600], d_loss: 1.1028, g_loss: 1.4072, D(x): 0.66, D(G(z)): 0.32
# Epoch [252/300], Step [600/600], d_loss: 0.8148, g_loss: 1.8567, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 0.9129, g_loss: 1.7805, D(x): 0.72, D(G(z)): 0.32
# Epoch [253/300], Step [400/600], d_loss: 0.9130, g_loss: 1.6408, D(x): 0.72, D(G(z)): 0.32
# Epoch [253/300], Step [600/600], d_loss: 0.7501, g_loss: 1.4979, D(x): 0.78, D(G(z)): 0.28
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 0.9284, g_loss: 1.5599, D(x): 0.75, D(G(z)): 0.36
# Epoch [254/300], Step [400/600], d_loss: 0.7877, g_loss: 1.4163, D(x): 0.77, D(G(z)): 0.30
# Epoch [254/300], Step [600/600], d_loss: 0.7772, g_loss: 1.2995, D(x): 0.73, D(G(z)): 0.30
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.8659, g_loss: 1.5259, D(x): 0.76, D(G(z)): 0.33
# Epoch [255/300], Step [400/600], d_loss: 0.8320, g_loss: 1.6036, D(x): 0.71, D(G(z)): 0.26
# Epoch [255/300], Step [600/600], d_loss: 0.9613, g_loss: 1.3456, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.7559, g_loss: 1.2682, D(x): 0.78, D(G(z)): 0.32
# Epoch [256/300], Step [400/600], d_loss: 0.8835, g_loss: 1.4346, D(x): 0.73, D(G(z)): 0.32
# Epoch [256/300], Step [600/600], d_loss: 0.9554, g_loss: 1.6432, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.8974, g_loss: 1.8275, D(x): 0.69, D(G(z)): 0.28
# Epoch [257/300], Step [400/600], d_loss: 1.0216, g_loss: 1.4439, D(x): 0.66, D(G(z)): 0.35
# Epoch [257/300], Step [600/600], d_loss: 0.8803, g_loss: 1.6316, D(x): 0.69, D(G(z)): 0.29
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 0.9982, g_loss: 1.2714, D(x): 0.75, D(G(z)): 0.38
# Epoch [258/300], Step [400/600], d_loss: 0.9678, g_loss: 1.6968, D(x): 0.66, D(G(z)): 0.28
# Epoch [258/300], Step [600/600], d_loss: 1.0422, g_loss: 1.0898, D(x): 0.68, D(G(z)): 0.35
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 0.8238, g_loss: 1.7052, D(x): 0.69, D(G(z)): 0.27
# Epoch [259/300], Step [400/600], d_loss: 0.9579, g_loss: 1.4983, D(x): 0.65, D(G(z)): 0.27
# Epoch [259/300], Step [600/600], d_loss: 0.8487, g_loss: 1.5534, D(x): 0.74, D(G(z)): 0.31
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 0.9378, g_loss: 1.5477, D(x): 0.67, D(G(z)): 0.29
# Epoch [260/300], Step [400/600], d_loss: 1.0059, g_loss: 1.5696, D(x): 0.62, D(G(z)): 0.26
# Epoch [260/300], Step [600/600], d_loss: 0.9668, g_loss: 1.6567, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.8803, g_loss: 1.5634, D(x): 0.71, D(G(z)): 0.28
# Epoch [261/300], Step [400/600], d_loss: 0.9435, g_loss: 1.6445, D(x): 0.64, D(G(z)): 0.27
# Epoch [261/300], Step [600/600], d_loss: 0.8113, g_loss: 1.6531, D(x): 0.76, D(G(z)): 0.32
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.8233, g_loss: 1.5809, D(x): 0.70, D(G(z)): 0.27
# Epoch [262/300], Step [400/600], d_loss: 1.0232, g_loss: 1.8667, D(x): 0.72, D(G(z)): 0.35
# Epoch [262/300], Step [600/600], d_loss: 1.0510, g_loss: 1.4930, D(x): 0.64, D(G(z)): 0.31
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 0.7760, g_loss: 1.3866, D(x): 0.74, D(G(z)): 0.28
# Epoch [263/300], Step [400/600], d_loss: 1.0516, g_loss: 1.2408, D(x): 0.73, D(G(z)): 0.40
# Epoch [263/300], Step [600/600], d_loss: 0.8130, g_loss: 1.8581, D(x): 0.72, D(G(z)): 0.27
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 1.0504, g_loss: 1.2581, D(x): 0.60, D(G(z)): 0.26
# Epoch [264/300], Step [400/600], d_loss: 1.1034, g_loss: 1.4448, D(x): 0.61, D(G(z)): 0.27
# Epoch [264/300], Step [600/600], d_loss: 1.0210, g_loss: 1.6969, D(x): 0.69, D(G(z)): 0.29
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 0.8999, g_loss: 1.3981, D(x): 0.71, D(G(z)): 0.31
# Epoch [265/300], Step [400/600], d_loss: 0.9052, g_loss: 1.1765, D(x): 0.70, D(G(z)): 0.32
# Epoch [265/300], Step [600/600], d_loss: 1.0516, g_loss: 1.4443, D(x): 0.64, D(G(z)): 0.32
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 0.8567, g_loss: 1.8227, D(x): 0.70, D(G(z)): 0.27
# Epoch [266/300], Step [400/600], d_loss: 0.8033, g_loss: 1.6890, D(x): 0.71, D(G(z)): 0.26
# Epoch [266/300], Step [600/600], d_loss: 1.0768, g_loss: 1.3605, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 0.8691, g_loss: 1.5691, D(x): 0.65, D(G(z)): 0.25
# Epoch [267/300], Step [400/600], d_loss: 1.0261, g_loss: 1.6150, D(x): 0.68, D(G(z)): 0.35
# Epoch [267/300], Step [600/600], d_loss: 0.8421, g_loss: 1.5135, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 1.0500, g_loss: 1.6361, D(x): 0.63, D(G(z)): 0.26
# Epoch [268/300], Step [400/600], d_loss: 0.9305, g_loss: 2.1467, D(x): 0.65, D(G(z)): 0.22
# Epoch [268/300], Step [600/600], d_loss: 0.9849, g_loss: 1.8212, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 0.8047, g_loss: 1.6945, D(x): 0.70, D(G(z)): 0.25
# Epoch [269/300], Step [400/600], d_loss: 0.7437, g_loss: 1.4565, D(x): 0.72, D(G(z)): 0.26
# Epoch [269/300], Step [600/600], d_loss: 0.9382, g_loss: 1.1532, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.9034, g_loss: 1.5442, D(x): 0.71, D(G(z)): 0.32
# Epoch [270/300], Step [400/600], d_loss: 0.8677, g_loss: 1.6578, D(x): 0.74, D(G(z)): 0.30
# Epoch [270/300], Step [600/600], d_loss: 0.8871, g_loss: 1.5616, D(x): 0.78, D(G(z)): 0.38
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 0.9280, g_loss: 1.6785, D(x): 0.68, D(G(z)): 0.29
# Epoch [271/300], Step [400/600], d_loss: 1.0753, g_loss: 1.3682, D(x): 0.68, D(G(z)): 0.34
# Epoch [271/300], Step [600/600], d_loss: 1.1199, g_loss: 1.2821, D(x): 0.63, D(G(z)): 0.34
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 0.8079, g_loss: 1.4384, D(x): 0.73, D(G(z)): 0.31
# Epoch [272/300], Step [400/600], d_loss: 0.9239, g_loss: 1.2414, D(x): 0.65, D(G(z)): 0.27
# Epoch [272/300], Step [600/600], d_loss: 0.9382, g_loss: 1.5542, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 0.8634, g_loss: 1.8606, D(x): 0.74, D(G(z)): 0.31
# Epoch [273/300], Step [400/600], d_loss: 0.9014, g_loss: 1.6970, D(x): 0.72, D(G(z)): 0.33
# Epoch [273/300], Step [600/600], d_loss: 1.1490, g_loss: 1.5034, D(x): 0.62, D(G(z)): 0.31
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 1.0730, g_loss: 1.7863, D(x): 0.61, D(G(z)): 0.26
# Epoch [274/300], Step [400/600], d_loss: 0.7797, g_loss: 1.7807, D(x): 0.69, D(G(z)): 0.22
# Epoch [274/300], Step [600/600], d_loss: 0.7680, g_loss: 1.4505, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.8732, g_loss: 1.6719, D(x): 0.79, D(G(z)): 0.38
# Epoch [275/300], Step [400/600], d_loss: 0.9325, g_loss: 1.6032, D(x): 0.72, D(G(z)): 0.34
# Epoch [275/300], Step [600/600], d_loss: 0.9667, g_loss: 1.6544, D(x): 0.73, D(G(z)): 0.34
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 0.9127, g_loss: 1.6851, D(x): 0.69, D(G(z)): 0.26
# Epoch [276/300], Step [400/600], d_loss: 0.8772, g_loss: 1.4512, D(x): 0.74, D(G(z)): 0.32
# Epoch [276/300], Step [600/600], d_loss: 0.8928, g_loss: 1.6383, D(x): 0.64, D(G(z)): 0.24
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 1.0477, g_loss: 1.3473, D(x): 0.69, D(G(z)): 0.36
# Epoch [277/300], Step [400/600], d_loss: 0.9144, g_loss: 1.4627, D(x): 0.73, D(G(z)): 0.32
# Epoch [277/300], Step [600/600], d_loss: 0.8807, g_loss: 1.4986, D(x): 0.63, D(G(z)): 0.21
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 0.8324, g_loss: 1.8528, D(x): 0.73, D(G(z)): 0.27
# Epoch [278/300], Step [400/600], d_loss: 0.7862, g_loss: 1.7221, D(x): 0.73, D(G(z)): 0.27
# Epoch [278/300], Step [600/600], d_loss: 1.0761, g_loss: 2.0993, D(x): 0.57, D(G(z)): 0.21
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 0.9547, g_loss: 1.4957, D(x): 0.70, D(G(z)): 0.30
# Epoch [279/300], Step [400/600], d_loss: 0.8493, g_loss: 1.5929, D(x): 0.72, D(G(z)): 0.31
# Epoch [279/300], Step [600/600], d_loss: 0.8103, g_loss: 1.7770, D(x): 0.70, D(G(z)): 0.24
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 1.0138, g_loss: 1.6418, D(x): 0.72, D(G(z)): 0.34
# Epoch [280/300], Step [400/600], d_loss: 0.9148, g_loss: 1.4888, D(x): 0.70, D(G(z)): 0.34
# Epoch [280/300], Step [600/600], d_loss: 0.9000, g_loss: 1.2305, D(x): 0.76, D(G(z)): 0.36
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.8146, g_loss: 1.4466, D(x): 0.79, D(G(z)): 0.37
# Epoch [281/300], Step [400/600], d_loss: 0.7996, g_loss: 1.6602, D(x): 0.72, D(G(z)): 0.27
# Epoch [281/300], Step [600/600], d_loss: 0.8314, g_loss: 1.9416, D(x): 0.75, D(G(z)): 0.27
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 0.9452, g_loss: 1.6436, D(x): 0.66, D(G(z)): 0.27
# Epoch [282/300], Step [400/600], d_loss: 1.1021, g_loss: 1.1695, D(x): 0.70, D(G(z)): 0.39
# Epoch [282/300], Step [600/600], d_loss: 0.9494, g_loss: 1.4833, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.8325, g_loss: 1.8003, D(x): 0.66, D(G(z)): 0.22
# Epoch [283/300], Step [400/600], d_loss: 0.9144, g_loss: 1.5568, D(x): 0.71, D(G(z)): 0.30
# Epoch [283/300], Step [600/600], d_loss: 0.8818, g_loss: 1.5451, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 1.0189, g_loss: 1.9839, D(x): 0.67, D(G(z)): 0.28
# Epoch [284/300], Step [400/600], d_loss: 0.9254, g_loss: 1.5669, D(x): 0.65, D(G(z)): 0.27
# Epoch [284/300], Step [600/600], d_loss: 1.0272, g_loss: 1.1309, D(x): 0.74, D(G(z)): 0.40
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.8259, g_loss: 1.7493, D(x): 0.70, D(G(z)): 0.27
# Epoch [285/300], Step [400/600], d_loss: 0.9673, g_loss: 1.8517, D(x): 0.61, D(G(z)): 0.23
# Epoch [285/300], Step [600/600], d_loss: 0.9711, g_loss: 1.3251, D(x): 0.70, D(G(z)): 0.35
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.8635, g_loss: 1.9804, D(x): 0.63, D(G(z)): 0.18
# Epoch [286/300], Step [400/600], d_loss: 0.9295, g_loss: 1.6331, D(x): 0.65, D(G(z)): 0.30
# Epoch [286/300], Step [600/600], d_loss: 0.8267, g_loss: 1.5525, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.9768, g_loss: 1.8133, D(x): 0.69, D(G(z)): 0.29
# Epoch [287/300], Step [400/600], d_loss: 0.8070, g_loss: 1.7079, D(x): 0.70, D(G(z)): 0.26
# Epoch [287/300], Step [600/600], d_loss: 0.7490, g_loss: 1.4011, D(x): 0.75, D(G(z)): 0.28
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 1.0028, g_loss: 1.7024, D(x): 0.65, D(G(z)): 0.29
# Epoch [288/300], Step [400/600], d_loss: 0.8435, g_loss: 1.5296, D(x): 0.71, D(G(z)): 0.29
# Epoch [288/300], Step [600/600], d_loss: 0.7875, g_loss: 1.9992, D(x): 0.72, D(G(z)): 0.28
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.8408, g_loss: 1.6283, D(x): 0.74, D(G(z)): 0.31
# Epoch [289/300], Step [400/600], d_loss: 0.9890, g_loss: 1.4753, D(x): 0.76, D(G(z)): 0.41
# Epoch [289/300], Step [600/600], d_loss: 0.9185, g_loss: 1.6623, D(x): 0.66, D(G(z)): 0.28
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.9704, g_loss: 1.3832, D(x): 0.63, D(G(z)): 0.25
# Epoch [290/300], Step [400/600], d_loss: 0.9246, g_loss: 1.3699, D(x): 0.69, D(G(z)): 0.32
# Epoch [290/300], Step [600/600], d_loss: 0.9345, g_loss: 1.7601, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 0.8534, g_loss: 1.5625, D(x): 0.68, D(G(z)): 0.28
# Epoch [291/300], Step [400/600], d_loss: 0.9493, g_loss: 1.5741, D(x): 0.65, D(G(z)): 0.29
# Epoch [291/300], Step [600/600], d_loss: 0.8051, g_loss: 1.3282, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 0.9151, g_loss: 1.5808, D(x): 0.72, D(G(z)): 0.32
# Epoch [292/300], Step [400/600], d_loss: 0.9071, g_loss: 1.7338, D(x): 0.63, D(G(z)): 0.19
# Epoch [292/300], Step [600/600], d_loss: 0.8988, g_loss: 1.7295, D(x): 0.63, D(G(z)): 0.25
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 0.9103, g_loss: 1.6488, D(x): 0.67, D(G(z)): 0.24
# Epoch [293/300], Step [400/600], d_loss: 0.8619, g_loss: 1.3643, D(x): 0.77, D(G(z)): 0.35
# Epoch [293/300], Step [600/600], d_loss: 0.9916, g_loss: 1.4455, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 0.9659, g_loss: 1.5062, D(x): 0.65, D(G(z)): 0.27
# Epoch [294/300], Step [400/600], d_loss: 0.9096, g_loss: 1.7180, D(x): 0.67, D(G(z)): 0.24
# Epoch [294/300], Step [600/600], d_loss: 0.9978, g_loss: 1.3913, D(x): 0.73, D(G(z)): 0.35
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 0.8179, g_loss: 1.7978, D(x): 0.71, D(G(z)): 0.27
# Epoch [295/300], Step [400/600], d_loss: 1.0983, g_loss: 1.6589, D(x): 0.66, D(G(z)): 0.31
# Epoch [295/300], Step [600/600], d_loss: 0.9927, g_loss: 1.4273, D(x): 0.71, D(G(z)): 0.36
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 0.8099, g_loss: 1.8748, D(x): 0.75, D(G(z)): 0.31
# Epoch [296/300], Step [400/600], d_loss: 0.9852, g_loss: 1.8874, D(x): 0.63, D(G(z)): 0.25
# Epoch [296/300], Step [600/600], d_loss: 0.9480, g_loss: 1.2563, D(x): 0.68, D(G(z)): 0.31
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 0.8332, g_loss: 1.6172, D(x): 0.70, D(G(z)): 0.25
# Epoch [297/300], Step [400/600], d_loss: 0.9606, g_loss: 1.4133, D(x): 0.67, D(G(z)): 0.31
# Epoch [297/300], Step [600/600], d_loss: 1.0382, g_loss: 1.4701, D(x): 0.71, D(G(z)): 0.38
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.9312, g_loss: 1.6630, D(x): 0.64, D(G(z)): 0.25
# Epoch [298/300], Step [400/600], d_loss: 1.0508, g_loss: 1.5168, D(x): 0.58, D(G(z)): 0.25
# Epoch [298/300], Step [600/600], d_loss: 0.8977, g_loss: 1.3845, D(x): 0.68, D(G(z)): 0.28
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 0.8680, g_loss: 1.7091, D(x): 0.74, D(G(z)): 0.31
# Epoch [299/300], Step [400/600], d_loss: 0.9352, g_loss: 1.2139, D(x): 0.72, D(G(z)): 0.33
# Epoch [299/300], Step [600/600], d_loss: 1.2791, g_loss: 1.3190, D(x): 0.70, D(G(z)): 0.45
# Saving fake_images-0300.png
# CPU times: user 2h 10min 58s, sys: 1min 27s, total: 2h 12min 25s
# Wall time: 2h 13min 29s

# %% [markdown]
# Now that we have trained the models, we can save checkpoints.

# %%
# Save the model checkpoints
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# Here's how the generated images look, after the 10th, 50th, 100th and 300th epochs of training.

# %%
Image('./samples/fake_images-0010.png')

# %%
Image('./samples/fake_images-0050.png')

# %%
Image('./samples/fake_images-0100.png')

# %%
Image('./samples/fake_images-0300.png')

# %% [markdown]
# We can visualize the training process by combining the sample images generated after each epoch into a video using OpenCV.

# %%
import cv2
import os
from IPython.display import FileLink

vid_fname = 'gans_training.avi'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname, cv2.VideoWriter_fourcc(*'MP4V'), 8, (302, 302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')
# Out:
# /content/gans_training.avi

# %% [markdown]
# We can also visualize how the loss changes over time. Visualizing losses is quite useful for debugging the training process. For GANs, we expect the generator's loss to reduce over time, without the discriminator's loss getting too high.

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses')
# Out:
# Text(0.5, 1.0, 'Losses')

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real score', 'Fake score'])
plt.title('Scores')
# Out:
# Text(0.5, 1.0, 'Scores')
